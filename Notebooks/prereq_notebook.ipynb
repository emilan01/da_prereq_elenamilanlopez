# %%
print("Hello from Elena!")
# Out:
# Hello from Elena!

# %% [markdown]
# Hello I am Elena
# I'm excited to learn data analysis and improve my Python skills.
# I’m especially interested in automation and using data to solve real-world problems.
